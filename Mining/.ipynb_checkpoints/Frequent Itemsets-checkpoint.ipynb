# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder

# %%
dfCrime = pd.read_csv("../Data/Crime_Data_Clean_Consolidated.csv")

# %%
dfCrime.head()
# Out:
#    Unnamed: 0         ID DateReported DateOccurred TimeOccurred  AreaID  \
# 0           0  180204779   2018-01-17   2010-01-01     00:01:00       2
# 1           1  172020383   2017-11-12   2010-01-01     00:01:00      20
# 2           2  171913109   2017-06-13   2010-01-01     00:01:00      19
# 3           3  172013071   2017-06-28   2010-01-01     00:01:00      20
# 4           4  171809308   2017-04-05   2010-01-01     00:01:00      18
#
#    ReportingDistrict  CrimeCode                             MOCodes  \
# 0                245        813            0510 0522 0558 1258 0602
# 1               2074        354                                0100
# 2               1994        354                           0377 1822
# 3               2025        820                           1257 0550
# 4               1891        760  0515 0913 1817 1820 0516 0500 0506
#
#    VictimAge  ...  DailyAverageDryBulbTemp DailyAverageRelativeHumidity  \
# 0         -1  ...                       60                           44
# 1         51  ...                       60                           44
# 2         42  ...                       60                           44
# 3         -1  ...                       60                           44
# 4         18  ...                       60                           44
#
#    DailySunrise  DailySunset DailyPrecip  DailySnowfall  DailySnowDepth  \
# 0      06:59:00     16:56:00         0.0            0.0             0.0
# 1      06:59:00     16:56:00         0.0            0.0             0.0
# 2      06:59:00     16:56:00         0.0            0.0             0.0
# 3      06:59:00     16:56:00         0.0            0.0             0.0
# 4      06:59:00     16:56:00         0.0            0.0             0.0
#
#    DailyAverageWindSpeed  DailyAverageHeatIndex night
# 0                    0.9                   82.6     1
# 1                    0.9                   82.6     1
# 2                    0.9                   82.6     1
# 3                    0.9                   82.6     1
# 4                    0.9                   82.6     1
#
# [5 rows x 42 columns]

# %% [markdown]
# Isolate the crime codes

# %%
crimeCodes = dfCrime[["CrimeCode", "CrimeCode1", "CrimeCode2", "CrimeCode3", "CrimeCode4"]]
crimeCodes.head(15)
# Out:
#     CrimeCode  CrimeCode1  CrimeCode2  CrimeCode3  CrimeCode4
# 0         813         813          -1          -1          -1
# 1         354         354          -1          -1          -1
# 2         354         354          -1          -1          -1
# 3         820         812         820          -1          -1
# 4         760         760          -1          -1          -1
# 5         121         121          -1          -1          -1
# 6         354         354          -1          -1          -1
# 7         354         354          -1          -1          -1
# 8         860         860          -1          -1          -1
# 9         121         121         812          -1          -1
# 10        820         812         820          -1          -1
# 11        812         812         860          -1          -1
# 12        354         354          -1          -1          -1
# 13        812         812         860          -1          -1
# 14        354         354          -1          -1          -1

# %% [markdown]
# This is a little weird. Some crime codes are in both `CrimeCode` and `CrimeCode1` or `CrimeCode` and `CrimeCode2`. There could be some situations where only `CrimeCode` is entered or `CrimeCode` contains a unique crime code, so I won't drop `CrimeCode` entirely.

# %%
crimeLists = []
for tup in crimeCodes.itertuples():
    # Quick and dirty, convert each row into a set and remove -1 from that set if possible
    # Then append that to a list of lists of crime codes
    crimeLists.append(list(set(tup[1:])-{-1}))

# %% [markdown]
# Any more cleaning?

# %%
crimeLists.index([])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-4315a221abef> in <module>()
# ----> 1 crimeLists.index([])
#
# ValueError: [] is not in list

# %% [markdown]
# Good! Time to transform this list of lists into something mlxtend can use for [apriori](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/).
#
# This might be a little expensive...

# %%
te = TransactionEncoder()
teItems = te.fit(crimeLists).transform(crimeLists)
dfTransformed = pd.DataFrame(teItems, columns=te.columns_)

# %%
dfTransformed.head()
# Out:
#      93     99     110    111    113    121    122    210    220    230  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False  False
#
#    ...      980    986    990    993    994    995    996    997    998    999
# 0  ...    False  False  False  False  False  False  False  False  False  False
# 1  ...    False  False  False  False  False  False  False  False  False  False
# 2  ...    False  False  False  False  False  False  False  False  False  False
# 3  ...    False  False  False  False  False  False  False  False  False  False
# 4  ...    False  False  False  False  False  False  False  False  False  False
#
# [5 rows x 163 columns]

# %% [markdown]
# Now for apriori:

# %%
# minumum support of 1% since the data is pretty sparse
apriori(dfTransformed, min_support=0.01)
# Out:
#      support itemsets
# 0   0.040058      [7]
# 1   0.042905      [9]
# 2   0.072255     [17]
# 3   0.076859     [19]
# 4   0.014378     [20]
# 5   0.035456     [21]
# 6   0.063130     [30]
# 7   0.040686     [32]
# 8   0.071616     [44]
# 9   0.022336     [46]
# 10  0.076893     [65]
# 11  0.092040     [70]
# 12  0.054711     [72]
# 13  0.012278     [76]
# 14  0.051024     [88]
# 15  0.045322     [89]
# 16  0.010092    [120]
# 17  0.029172    [132]
# 18  0.010888    [141]
# 19  0.010302    [149]
# 20  0.053142    [161]

# %% [markdown]
# This is only 1 itemsets :/

# %%
apriori(dfTransformed, min_support=0.005)
# Out:
#      support   itemsets
# 0   0.040058        [7]
# 1   0.005695        [8]
# 2   0.042905        [9]
# 3   0.005817       [13]
# 4   0.072255       [17]
# 5   0.006232       [18]
# 6   0.076859       [19]
# 7   0.014378       [20]
# 8   0.035456       [21]
# 9   0.006652       [26]
# 10  0.063130       [30]
# 11  0.040686       [32]
# 12  0.071616       [44]
# 13  0.022336       [46]
# 14  0.006569       [61]
# 15  0.076893       [65]
# 16  0.092040       [70]
# 17  0.054711       [72]
# 18  0.012278       [76]
# 19  0.051024       [88]
# 20  0.045322       [89]
# 21  0.006000       [94]
# 22  0.006154      [111]
# 23  0.009332      [118]
# 24  0.010092      [120]
# 25  0.008690      [121]
# 26  0.029172      [132]
# 27  0.010888      [141]
# 28  0.010302      [149]
# 29  0.053142      [161]
# 30  0.008848   [9, 161]
# 31  0.006070  [17, 161]

# %% [markdown]
# Some 2 itemsets here. That's better. But these will stay if we lower the minimum support...

# %%
apriori(dfTransformed, min_support=0.001)
# Out:
#      support    itemsets
# 0   0.001359         [2]
# 1   0.004669         [5]
# 2   0.040058         [7]
# 3   0.005695         [8]
# 4   0.042905         [9]
# 5   0.005817        [13]
# 6   0.002809        [14]
# 7   0.001289        [16]
# 8   0.072255        [17]
# 9   0.006232        [18]
# 10  0.076859        [19]
# 11  0.014378        [20]
# 12  0.035456        [21]
# 13  0.001755        [22]
# 14  0.006652        [26]
# 15  0.063130        [30]
# 16  0.001470        [31]
# 17  0.040686        [32]
# 18  0.001672        [41]
# 19  0.071616        [44]
# 20  0.022336        [46]
# 21  0.006569        [61]
# 22  0.076893        [65]
# 23  0.001681        [66]
# 24  0.002181        [69]
# 25  0.092040        [70]
# 26  0.001287        [71]
# 27  0.054711        [72]
# 28  0.004342        [73]
# 29  0.001684        [75]
# ..       ...         ...
# 40  0.002647       [101]
# 41  0.001041       [103]
# 42  0.001665       [110]
# 43  0.006154       [111]
# 44  0.001742       [117]
# 45  0.009332       [118]
# 46  0.010092       [120]
# 47  0.008690       [121]
# 48  0.001638       [123]
# 49  0.001514       [125]
# 50  0.001602       [131]
# 51  0.029172       [132]
# 52  0.001080       [136]
# 53  0.010888       [141]
# 54  0.001071       [145]
# 55  0.010302       [149]
# 56  0.053142       [161]
# 57  0.001856    [5, 161]
# 58  0.003902    [7, 161]
# 59  0.008848    [9, 161]
# 60  0.006070   [17, 161]
# 61  0.002520   [19, 161]
# 62  0.001694   [44, 161]
# 63  0.002066   [46, 161]
# 64  0.001292   [70, 161]
# 65  0.001638   [72, 161]
# 66  0.003322   [88, 161]
# 67  0.001620   [89, 161]
# 68  0.001951  [132, 161]
# 69  0.001442  [141, 161]
#
# [70 rows x 2 columns]

# %% [markdown]
# There are about 1.6 million crimes here, so 0.1% of that is still 1600 crimes with the same crime codes. This minimum support, while small, is still not too specific.
#
# It would be interesting to see if at least 500 crimes shared the same crime code. To capture that, we would need a minimum support of ~0.0003.
#
# This might take a while.

# %%
freqCrimes = apriori(dfTransformed, min_support=0.0003, use_colnames=True)

# %%
freqCrimes
# Out:
#       support    itemsets
# 0    0.001359       [110]
# 1    0.004669       [121]
# 2    0.000552       [122]
# 3    0.040058       [210]
# 4    0.005695       [220]
# 5    0.042905       [230]
# 6    0.000798       [231]
# 7    0.000814       [235]
# 8    0.005817       [236]
# 9    0.002809       [237]
# 10   0.001289       [251]
# 11   0.072255       [310]
# 12   0.006232       [320]
# 13   0.076859       [330]
# 14   0.014378       [331]
# 15   0.035456       [341]
# 16   0.001755       [343]
# 17   0.006652       [350]
# 18   0.000645       [351]
# 19   0.000385       [352]
# 20   0.063130       [354]
# 21   0.001470       [410]
# 22   0.040686       [420]
# 23   0.000595       [421]
# 24   0.000493       [434]
# 25   0.001672       [437]
# 26   0.071616       [440]
# 27   0.000833       [441]
# 28   0.022336       [442]
# 29   0.006569       [480]
# ..        ...         ...
# 83   0.003902  [210, 998]
# 84   0.000638  [220, 998]
# 85   0.008848  [230, 998]
# 86   0.000657  [236, 998]
# 87   0.000532  [251, 998]
# 88   0.006070  [310, 998]
# 89   0.000495  [320, 998]
# 90   0.002520  [330, 998]
# 91   0.000998  [341, 998]
# 92   0.000402  [354, 649]
# 93   0.000532  [354, 998]
# 94   0.000619  [420, 998]
# 95   0.000526  [440, 480]
# 96   0.001694  [440, 998]
# 97   0.002066  [442, 998]
# 98   0.001292  [624, 998]
# 99   0.001638  [626, 998]
# 100  0.000962  [649, 998]
# 101  0.003322  [740, 998]
# 102  0.001620  [745, 998]
# 103  0.000957  [753, 998]
# 104  0.000790  [761, 930]
# 105  0.000888  [761, 998]
# 106  0.000974  [812, 860]
# 107  0.000570  [812, 998]
# 108  0.000338  [815, 998]
# 109  0.000707  [888, 998]
# 110  0.000468  [900, 998]
# 111  0.001951  [930, 998]
# 112  0.001442  [946, 998]
#
# [113 rows x 2 columns]

# %% [markdown]
# That's better

# %%
freqCrimes["length"] = freqCrimes.apply(lambda row: len(row["itemsets"]), axis=1)
freqCrimes.head()
# Out:
#     support itemsets  length
# 0  0.001359    [110]       1
# 1  0.004669    [121]       1
# 2  0.000552    [122]       1
# 3  0.040058    [210]       1
# 4  0.005695    [220]       1

# %% [markdown]
# Now to import the labels

# %%
dfLabels = pd.read_csv("../Data/CrimeCodeDescriptions.csv")
dfLabels.head()
# Out:
#    CrimeCode            CrimeCodeDescription
# 0        510                VEHICLE - STOLEN
# 1        440  THEFT PLAIN - PETTY ($950 & UN
# 2        626  INTIMATE PARTNER - SIMPLE ASSA
# 3        900        VIOLATION OF COURT ORDER
# 4        740  VANDALISM - FELONY ($400 & OVE

# %%
def lookupCode(code):
    return list(dfLabels.loc[dfLabels["CrimeCode"] == code]["CrimeCodeDescription"])

def translate(row):
    ccs = row["itemsets"]
    t = []
    for entry in ccs:
        t += lookupCode(entry)
    return t

# %%
freqCrimes["translated"] = freqCrimes.apply(translate, axis=1)

# %%
nFreqItems = freqCrimes.loc[freqCrimes["length"] > 1]

# %%
nFreqItems
# Out:
#       support    itemsets  length  \
# 81   0.000597  [110, 998]       2
# 82   0.001856  [121, 998]       2
# 83   0.003902  [210, 998]       2
# 84   0.000638  [220, 998]       2
# 85   0.008848  [230, 998]       2
# 86   0.000657  [236, 998]       2
# 87   0.000532  [251, 998]       2
# 88   0.006070  [310, 998]       2
# 89   0.000495  [320, 998]       2
# 90   0.002520  [330, 998]       2
# 91   0.000998  [341, 998]       2
# 92   0.000402  [354, 649]       2
# 93   0.000532  [354, 998]       2
# 94   0.000619  [420, 998]       2
# 95   0.000526  [440, 480]       2
# 96   0.001694  [440, 998]       2
# 97   0.002066  [442, 998]       2
# 98   0.001292  [624, 998]       2
# 99   0.001638  [626, 998]       2
# 100  0.000962  [649, 998]       2
# 101  0.003322  [740, 998]       2
# 102  0.001620  [745, 998]       2
# 103  0.000957  [753, 998]       2
# 104  0.000790  [761, 930]       2
# 105  0.000888  [761, 998]       2
# 106  0.000974  [812, 860]       2
# 107  0.000570  [812, 998]       2
# 108  0.000338  [815, 998]       2
# 109  0.000707  [888, 998]       2
# 110  0.000468  [900, 998]       2
# 111  0.001951  [930, 998]       2
# 112  0.001442  [946, 998]       2
#
#                                             translated
# 81                                 [CRIMINAL HOMICIDE]
# 82                                    [RAPE, FORCIBLE]
# 83                                           [ROBBERY]
# 84                                 [ATTEMPTED ROBBERY]
# 85                    [ASSAULT WITH DEADLY WEAPON, AG]
# 86                    [INTIMATE PARTNER - AGGRAVATED ]
# 87                    [SHOTS FIRED AT INHABITED DWELL]
# 88                                          [BURGLARY]
# 89                               [BURGLARY, ATTEMPTED]
# 90                             [BURGLARY FROM VEHICLE]
# 91                    [THEFT-GRAND ($950.01 & OVER)EX]
# 92   [THEFT OF IDENTITY, DOCUMENT FORGERY / STOLEN ...
# 93                                 [THEFT OF IDENTITY]
# 94                    [THEFT FROM MOTOR VEHICLE - PET]
# 95     [THEFT PLAIN - PETTY ($950 & UN, BIKE - STOLEN]
# 96                    [THEFT PLAIN - PETTY ($950 & UN]
# 97                    [SHOPLIFTING - PETTY THEFT ($95]
# 98                          [BATTERY - SIMPLE ASSAULT]
# 99                    [INTIMATE PARTNER - SIMPLE ASSA]
# 100                   [DOCUMENT FORGERY / STOLEN FELO]
# 101                   [VANDALISM - FELONY ($400 & OVE]
# 102                   [VANDALISM - MISDEAMEANOR ($399]
# 103                   [DISCHARGE FIREARMS/SHOTS FIRED]
# 104  [BRANDISH WEAPON, CRIMINAL THREATS - NO WEAPON D]
# 105                                  [BRANDISH WEAPON]
# 106  [CRM AGNST CHLD (13 OR UNDER) (, BATTERY WITH ...
# 107                   [CRM AGNST CHLD (13 OR UNDER) (]
# 108  [SEXUAL PENTRATION WITH A FOREI, SEXUAL PENETR...
# 109                                      [TRESPASSING]
# 110                         [VIOLATION OF COURT ORDER]
# 111                   [CRIMINAL THREATS - NO WEAPON D]
# 112                        [OTHER MISCELLANEOUS CRIME]

# %%
lookupCode(998)
# Out:
# []

# %% [markdown]
# Code 998 is actually a filler

# %%
freqCrimes["hasFiller"] = freqCrimes.apply(lambda row: 1 if 998 in row["itemsets"] else 0, axis = 1)

# %%
useful = freqCrimes.loc[freqCrimes["hasFiller"] == 0]

# %%
useful.sort_values(by="support", ascending=False).head(30)
# Out:
#      support itemsets  length  \
# 33  0.092040    [624]       1
# 30  0.076893    [510]       1
# 13  0.076859    [330]       1
# 11  0.072255    [310]       1
# 26  0.071616    [440]       1
# 20  0.063130    [354]       1
# 35  0.054711    [626]       1
# 46  0.051024    [740]       1
# 47  0.045322    [745]       1
# 5   0.042905    [230]       1
# 22  0.040686    [420]       1
# 3   0.040058    [210]       1
# 15  0.035456    [341]       1
# 71  0.029172    [930]       1
# 28  0.022336    [442]       1
# 14  0.014378    [331]       1
# 39  0.012278    [649]       1
# 76  0.010888    [946]       1
# 78  0.010302    [956]       1
# 63  0.010092    [900]       1
# 62  0.009332    [888]       1
# 64  0.008690    [901]       1
# 17  0.006652    [350]       1
# 29  0.006569    [480]       1
# 12  0.006232    [320]       1
# 60  0.006154    [860]       1
# 50  0.006000    [761]       1
# 8   0.005817    [236]       1
# 4   0.005695    [220]       1
# 54  0.004876    [812]       1
#
#                                          translated  hasFiller
# 33                       [BATTERY - SIMPLE ASSAULT]          0
# 30                               [VEHICLE - STOLEN]          0
# 13                          [BURGLARY FROM VEHICLE]          0
# 11                                       [BURGLARY]          0
# 26                 [THEFT PLAIN - PETTY ($950 & UN]          0
# 20                              [THEFT OF IDENTITY]          0
# 35                 [INTIMATE PARTNER - SIMPLE ASSA]          0
# 46                 [VANDALISM - FELONY ($400 & OVE]          0
# 47                 [VANDALISM - MISDEAMEANOR ($399]          0
# 5                  [ASSAULT WITH DEADLY WEAPON, AG]          0
# 22                 [THEFT FROM MOTOR VEHICLE - PET]          0
# 3                                         [ROBBERY]          0
# 15                 [THEFT-GRAND ($950.01 & OVER)EX]          0
# 71                 [CRIMINAL THREATS - NO WEAPON D]          0
# 28                 [SHOPLIFTING - PETTY THEFT ($95]          0
# 14                 [THEFT FROM MOTOR VEHICLE - GRA]          0
# 39                 [DOCUMENT FORGERY / STOLEN FELO]          0
# 76                      [OTHER MISCELLANEOUS CRIME]          0
# 78  [LETTERS, LEWD, LETTERS, LEWD  -  TELEPHONE CA]          0
# 63                       [VIOLATION OF COURT ORDER]          0
# 62                                    [TRESPASSING]          0
# 64                 [VIOLATION OF RESTRAINING ORDER]          0
# 17                                  [THEFT, PERSON]          0
# 29                                  [BIKE - STOLEN]          0
# 12                            [BURGLARY, ATTEMPTED]          0
# 60                    [BATTERY WITH SEXUAL CONTACT]          0
# 50                                [BRANDISH WEAPON]          0
# 8                  [INTIMATE PARTNER - AGGRAVATED ]          0
# 4                               [ATTEMPTED ROBBERY]          0
# 54                 [CRM AGNST CHLD (13 OR UNDER) (]          0

# %% [markdown]
# The most frequent two item sets:

# %%
nFreqItems = useful.loc[useful["length"] > 1].sort_values(by="support", ascending=False)
for i, r in nFreqItems.iterrows():
    print(r["support"], r["translated"])
# Out:
# 0.0009741800149799746 ['CRM AGNST CHLD (13 OR UNDER) (', 'BATTERY WITH SEXUAL CONTACT']
# 0.0007899407785251709 ['BRANDISH WEAPON', 'CRIMINAL THREATS - NO WEAPON D']
# 0.0005262257930114325 ['THEFT PLAIN - PETTY ($950 & UN', 'BIKE - STOLEN']
# 0.0004021954573588523 ['THEFT OF IDENTITY', 'DOCUMENT FORGERY / STOLEN FELO']

# %% [markdown]
# # Results
# ---
# The most frequent individual crimes are
#
# | Crime |
# |-|
# |BATTERY - SIMPLE ASSAULT|
# |VEHICLE - STOLEN|
# |BURGLARY FROM VEHICLE|
# |BURGLARY|
# |THEFT PLAIN - PETTY ($950 & UN|
#
# The most frequent 2 itemsets for crime codes are
#
# | Crime 1 | Crime 2 |
# |-|-|
# |CRM AGNST CHLD (13 OR UNDER) | BATTERY WITH SEXUAL CONTACT|
# |BRANDISH WEAPON|CRIMINAL THREATS - NO WEAPON D|
# |THEFT PLAIN - PETTY ($950 & UN | BIKE - STOLEN|
# |THEFT OF IDENTITY| DOCUMENT FORGERY / STOLEN FELONY|
